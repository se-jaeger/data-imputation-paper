# %% [markdown]
# Basically, there are 3 different types of tasks:
#
# 1. Regression
# 2. Binary Classification
# 3. Mulitclass Classification
#
# However, we can split them further:
#
# 3. Mulitclass Classification into ..
#     - 3-class
#     - 4-class
#     - ...
#
# For all three we can split based on their features.. only
# - numerical
# - categorical
# - mixed

# %%
import openml

import pandas as pd

# %% [markdown]
# ## Filtering available datasets
#
# - Active datasets
# - No missing values
#     - If we have missing values in the original dataset, we can not trust the downstream task performance changes
# - At least 5000 instances
# - At least 5 features
# - Drop duplicated datasets
# - Drop datasets with no information about the number of classes
# - (At the end) we only use 50 datasets for each task (regression, binary, multiclass)

# %%
# First get all available datasets
all_datasets = openml.tasks.list_tasks(output_format="dataframe")

# %% [markdown]
# # TODO
#
# We probably want to filter here for `source_data` to catch all duplicated/augmented datasets..

# %%
datasets = all_datasets.copy()

# Datasets without missing values
datasets = datasets[datasets["NumberOfInstancesWithMissingValues"] == 0]

# Active datasets
datasets = datasets[datasets["status"] == "active"]

# Rename 
datasets = datasets.rename(columns={"NumberOfSymbolicFeatures": "NumberOfCategoricalFeatures"})

# Only look at datasets with at least 5000 instances and at least 5 features
datasets = datasets[datasets["NumberOfInstances"] >= 3000]
datasets = datasets[datasets["NumberOfFeatures"] >= 5]

# drop some corrupted datasets
datasets = datasets[~datasets["NumberOfClasses"].isna()]

# drop some unused columns
datasets = datasets.drop(columns=[
    "tid", "ttid", "task_type", "estimation_procedure", "evaluation_measures",
    "cost_matrix", "MaxNominalAttDistinctValues", "status", "target_value",
    "NumberOfMissingValues", "target_feature", "source_data", "number_samples",
    "source_data_labeled", "target_feature_event", "target_feature_left",
    "target_feature_right", "quality_measure", "NumberOfInstancesWithMissingValues"
])

# drop datasets that are very similiar. I.e., where the datasets consists of the same "shape"
columns_to_check_duplicates = datasets.columns.tolist()
columns_to_check_duplicates.remove("did")
columns_to_check_duplicates.remove("name")
columns_to_check_duplicates.remove("MinorityClassSize")
columns_to_check_duplicates.remove("MajorityClassSize")
datasets[columns_to_check_duplicates].astype(int)
datasets = datasets.drop_duplicates(columns_to_check_duplicates)

# %% [markdown]
# ### Regression datasets
#
# Regression datasets are datasets with `0` classes.

# %%
regression = datasets[datasets["NumberOfClasses"] == 0].copy()

# drop some unused columns
regression = regression.drop(columns=[
    "MajorityClassSize", "MinorityClassSize", "NumberOfClasses"
])

# Sort
regression = regression.sort_values(["NumberOfFeatures", "NumberOfInstances"])

regression = regression.reset_index(drop=True)

# %%
regression[:50]
# Out:
#       did                                  name  NumberOfFeatures  \
# 0     529                                pollen               5.0
# 1    1433                             svmguide1               5.0
# 2     688                      visualizing_soil               5.0
# 3   23395                       COMET_MC_SAMPLE               6.0
# 4   23397                       COMET_MC_SAMPLE               6.0
# 5    5648                              COMET_MC               6.0
# 6     507                              space_ga               7.0
# 7   42545                    stock_fardamento02               7.0
# 8     198                       delta_elevators               7.0
# 9   23515                                sulfur               7.0
# 10    504                   analcatdata_supreme               8.0
# 11  42726                               abalone               9.0
# 12    189                                kin8nm               9.0
# 13    537                                houses               9.0
# 14    218                              house_8L               9.0
# 15   1199                       BNG(echoMonths)              10.0
# 16   1193                           BNG(lowbwt)              10.0
# 17  42225                              diamonds              10.0
# 18   1200                            BNG(stock)              10.0
# 19   1201                      BNG(breastTumor)              10.0
# 20  41540                          black_friday              10.0
# 21  42207         particulate-matter-ukair-2017              10.0
# 22  42721                  Airlines_DepDelay_1M              10.0
# 23  42728                 Airlines_DepDelay_10M              10.0
# 24  42675                          auml_eml_1_d              11.0
# 25    215                              2dplanes              11.0
# 26    344                                    mv              11.0
# 27   1213                               BNG(mv)              11.0
# 28   1203                         BNG(pwLinear)              11.0
# 29   1595                                 poker              11.0
# 30    287                          wine_quality              12.0
# 31   1414  Kaggle_bike_sharing_demand_challange              12.0
# 32  42130                       medical_charges              12.0
# 33  42559               medical_charges_nominal              12.0
# 34   1204                     BNG(wine_quality)              12.0
# 35   1196                          BNG(pharynx)              12.0
# 36    227                             cpu_small              13.0
# 37  42688                      Brazilian_houses              13.0
# 38  42712                   Bike_Sharing_Demand              13.0
# 39  42713                   Bike_Sharing_Demand              13.0
# 40  42669                            auml_url_2              13.0
# 41   1202                        BNG(cpu_small)              13.0
# 42   1188                        BNG(cleveland)              14.0
# 43    503                                  wind              15.0
# 44  42183                         dataset_sales              15.0
# 45  42208               nyc-taxi-green-dec-2016              15.0
# 46   1195                        BNG(autoPrice)              16.0
# 47   1189                       BNG(auto_price)              16.0
# 48    574                             house_16H              17.0
# 49    216                             elevators              19.0
#
#     NumberOfInstances  NumberOfNumericFeatures  NumberOfCategoricalFeatures
# 0              3848.0                      5.0                          0.0
# 1              7089.0                      5.0                          0.0
# 2              8641.0                      4.0                          1.0
# 3             89640.0                      6.0                          0.0
# 4            761940.0                      6.0                          0.0
# 5           7619400.0                      6.0                          0.0
# 6              3107.0                      7.0                          0.0
# 7              6277.0                      6.0                          1.0
# 8              9517.0                      7.0                          0.0
# 9             10081.0                      7.0                          0.0
# 10             4052.0                      8.0                          0.0
# 11             4177.0                      8.0                          1.0
# 12             8192.0                      9.0                          0.0
# 13            20640.0                      9.0                          0.0
# 14            22784.0                      9.0                          0.0
# 15            17496.0                      7.0                          3.0
# 16            31104.0                      3.0                          7.0
# 17            53940.0                      7.0                          3.0
# 18            59049.0                     10.0                          0.0
# 19           116640.0                      2.0                          8.0
# 20           166821.0                      6.0                          4.0
# 21           394299.0                      4.0                          5.0
# 22          1000000.0                      7.0                          3.0
# 23         10000000.0                      7.0                          3.0
# 24             4585.0                     11.0                          0.0
# 25            40768.0                     11.0                          0.0
# 26            40768.0                      8.0                          3.0
# 27            78732.0                      8.0                          3.0
# 28           177147.0                     11.0                          0.0
# 29          1025010.0                     11.0                          0.0
# 30             6497.0                     12.0                          0.0
# 31            10886.0                      6.0                          6.0
# 32           163065.0                      6.0                          2.0
# 33           163065.0                      4.0                          8.0
# 34           531441.0                     12.0                          0.0
# 35          1000000.0                      2.0                         10.0
# 36             8192.0                     13.0                          0.0
# 37            10692.0                      9.0                          4.0
# 38            17379.0                      9.0                          4.0
# 39            17379.0                     11.0                          2.0
# 40            95911.0                     13.0                          0.0
# 41          1000000.0                     13.0                          0.0
# 42          1000000.0                      7.0                          7.0
# 43             6574.0                     15.0                          0.0
# 44            10738.0                     15.0                          0.0
# 45           581835.0                      4.0                          9.0
# 46          1000000.0                     16.0                          0.0
# 47          1000000.0                     15.0                          1.0
# 48            22784.0                     17.0                          0.0
# 49            16599.0                     19.0                          0.0

# %% [markdown]
# ### Classification datasets
#
# #### Binary Classification datasets
#
# Binary Classification datasets are datasets with `2` classes.

# %%
binary_classification = datasets[datasets["NumberOfClasses"] == 2].copy()

# drop some unused columns
binary_classification = binary_classification.drop(columns=[
    "NumberOfClasses"
])

# Sort
binary_classification = binary_classification.sort_values(["NumberOfFeatures", "NumberOfInstances"])

binary_classification = binary_classification.reset_index(drop=True)

# %%
binary_classification[:50]
# Out:
#       did                                name  MajorityClassSize  \
# 0     923                    visualizing_soil             4753.0
# 1     871                              pollen             1924.0
# 2   40983                                wilt             4578.0
# 3    1489                             phoneme             3818.0
# 4     803                      delta_ailerons             3783.0
# 5    1046                            mozilla4            10437.0
# 6     737                            space_ga             1566.0
# 7     819                     delta_elevators             4785.0
# 8     310                         mammography            10923.0
# 9   40922             Run_or_walk_information            44365.0
# 10  42344                 sf-police-incidents           269319.0
# 11    728                 analcatdata_supreme             3081.0
# 12  42493                            airlines            14934.0
# 13   1169                            airlines           299119.0
# 14    720                             abalone             2096.0
# 15    725                             bank8FM             4885.0
# 16    959                             nursery             8640.0
# 17    823                              houses            11726.0
# 18    843                            house_8L            16040.0
# 19    151                         electricity            26075.0
# 20    351                              codrna           325710.0
# 21  42732                 sf-police-incidents          1945704.0
# 22   4135              Amazon_employee_access            30872.0
# 23    137                    BNG(tic-tac-toe)            25702.0
# 24    251                       BNG(breast-w)            25820.0
# 25   1220              Click_prediction_small            33220.0
# 26     77  BNG(breast-cancer,nominal,1000000)           702823.0
# 27   1235                            Agrawal1           672045.0
# 28   1216              Click_prediction_small          1429610.0
# 29   1021                         page-blocks             4913.0
# 30    727                            2dplanes            20420.0
# 31    881                                  mv            24321.0
# 32    152                  Hyperplane_10_1E-3           500007.0
# 33    354                               poker           513702.0
# 34   1120                      MagicTelescope            12332.0
# 35  41434              Click_prediction_small            33220.0
# 36  41709              FOREX_audchf-hour-High            22481.0
# 37   1217              Click_prediction_small           142949.0
# 38  41708           FOREX_eurchf-minute-Close           194808.0
# 39   1219              Click_prediction_small           332393.0
# 40   1218              Click_prediction_small          1664406.0
# 41    735                           cpu_small             5715.0
# 42   1178                    BNG(solar-flare)           648320.0
# 43  42192                    compas-two-years             2795.0
# 44    140  BNG(heart-statlog,nominal,1000000)           554324.0
# 45    267                  BNG(heart-statlog)           555946.0
# 46    847                                wind             3501.0
# 47    976                      JapaneseVowels             8347.0
# 48   1471                       eeg-eye-state             8257.0
# 49   1182                          BNG(adult)           759864.0
#
#     MinorityClassSize  NumberOfFeatures  NumberOfInstances  \
# 0              3888.0               5.0             8641.0
# 1              1924.0               6.0             3848.0
# 2               261.0               6.0             4839.0
# 3              1586.0               6.0             5404.0
# 4              3346.0               6.0             7129.0
# 5              5108.0               6.0            15545.0
# 6              1541.0               7.0             3107.0
# 7              4732.0               7.0             9517.0
# 8               260.0               7.0            11183.0
# 9             44223.0               7.0            88588.0
# 10           269319.0               7.0           538638.0
# 11              971.0               8.0             4052.0
# 12            12035.0               8.0            26969.0
# 13           240264.0               8.0           539383.0
# 14             2081.0               9.0             4177.0
# 15             3307.0               9.0             8192.0
# 16             4320.0               9.0            12960.0
# 17             8914.0               9.0            20640.0
# 18             6744.0               9.0            22784.0
# 19            19237.0               9.0            45312.0
# 20           162855.0               9.0           488565.0
# 21           269319.0               9.0          2215023.0
# 22             1897.0              10.0            32769.0
# 23            13664.0              10.0            39366.0
# 24            13546.0              10.0            39366.0
# 25             6728.0              10.0            39948.0
# 26           297177.0              10.0          1000000.0
# 27           327955.0              10.0          1000000.0
# 28            66781.0              10.0          1496391.0
# 29              560.0              11.0             5473.0
# 30            20348.0              11.0            40768.0
# 31            16447.0              11.0            40768.0
# 32           499993.0              11.0          1000000.0
# 33           511308.0              11.0          1025010.0
# 34             6688.0              12.0            19020.0
# 35             6728.0              12.0            39948.0
# 36            21344.0              12.0            43825.0
# 37             6690.0              12.0           149639.0
# 38           181032.0              12.0           375840.0
# 39            67089.0              12.0           399482.0
# 40           333004.0              12.0          1997410.0
# 41             2477.0              13.0             8192.0
# 42            15232.0              13.0           663552.0
# 43             2483.0              14.0             5278.0
# 44           445676.0              14.0          1000000.0
# 45           444054.0              14.0          1000000.0
# 46             3073.0              15.0             6574.0
# 47             1614.0              15.0             9961.0
# 48             6723.0              15.0            14980.0
# 49           240136.0              15.0          1000000.0
#
#     NumberOfNumericFeatures  NumberOfCategoricalFeatures
# 0                       3.0                          2.0
# 1                       5.0                          1.0
# 2                       5.0                          1.0
# 3                       5.0                          1.0
# 4                       5.0                          1.0
# 5                       5.0                          1.0
# 6                       6.0                          1.0
# 7                       6.0                          1.0
# 8                       6.0                          1.0
# 9                       6.0                          1.0
# 10                      1.0                          6.0
# 11                      7.0                          1.0
# 12                      2.0                          6.0
# 13                      3.0                          5.0
# 14                      7.0                          2.0
# 15                      8.0                          1.0
# 16                      0.0                          9.0
# 17                      8.0                          1.0
# 18                      8.0                          1.0
# 19                      7.0                          2.0
# 20                      8.0                          1.0
# 21                      3.0                          6.0
# 22                      0.0                         10.0
# 23                      0.0                         10.0
# 24                      9.0                          1.0
# 25                      9.0                          1.0
# 26                      0.0                         10.0
# 27                      6.0                          4.0
# 28                      9.0                          1.0
# 29                     10.0                          1.0
# 30                     10.0                          1.0
# 31                      7.0                          4.0
# 32                     10.0                          1.0
# 33                     10.0                          1.0
# 34                     11.0                          1.0
# 35                      5.0                          7.0
# 36                     11.0                          1.0
# 37                     11.0                          1.0
# 38                     11.0                          1.0
# 39                     11.0                          1.0
# 40                     11.0                          1.0
# 41                     12.0                          1.0
# 42                      0.0                         13.0
# 43                      7.0                          7.0
# 44                      0.0                         14.0
# 45                     13.0                          1.0
# 46                     14.0                          1.0
# 47                     14.0                          1.0
# 48                     14.0                          1.0
# 49                      2.0                         13.0

# %% [markdown]
# #### Multiclass Classification datasets
#
# Multiclass Classification datasets are datasets with more than `2` classes.

# %%
multiclass_classification = datasets[datasets["NumberOfClasses"] > 2].copy()

# Sort
multiclass_classification = multiclass_classification.sort_values(["NumberOfClasses", "NumberOfFeatures", "NumberOfInstances"])

# reset indices
multiclass_classification = multiclass_classification.reset_index(drop=True)

# %%
multiclass_classification[:50]
# Out:
#       did                                    name  MajorityClassSize  \
# 0   41027  jungle_chess_2pcs_raw_endgame_complete            23062.0
# 1    1557                                 abalone             1447.0
# 2     119                  BNG(cmc,nominal,55296)            23655.0
# 3     255                                BNG(cmc)            23567.0
# 4    1226                  Click_prediction_small           399482.0
# 5    1179                        BNG(solar-flare)           994382.0
# 6    1185                               BNG(wine)           401055.0
# 7    1222         letter-challenge-unlabeled.arff            10000.0
# 8   40497                             thyroid-ann             3488.0
# 9    1044                           eye_movements             4262.0
# 10  40707                                   allbp             3609.0
# 11     60                           waveform-5000             1692.0
# 12    147      BNG(waveform-5000,nominal,1000000)           337805.0
# 13    271                      BNG(waveform-5000)           338402.0
# 14  40668                               connect-4            44473.0
# 15  40997  jungle_chess_2pcs_endgame_panther_lion             2523.0
# 16   4541                           Diabetes130US            54864.0
# 17     46                                  splice             1655.0
# 18  40670                                     dna             1654.0
# 19   1526                   wall-robot-navigation             2205.0
# 20   1568                                 nursery             4320.0
# 21     76              BNG(lymph,nominal,1000000)           543512.0
# 22    249                              BNG(lymph)           543495.0
# 23    268                            BNG(vehicle)           257546.0
# 24   1497                   wall-robot-navigation             2205.0
# 25  40708                                  allrep             3648.0
# 26    144        BNG(hypothyroid,nominal,1000000)           922578.0
# 27  41168                                  jannis            38522.0
# 28     26                                 nursery             4320.0
# 29     30                             page-blocks             4913.0
# 30    125         BNG(page-blocks,nominal,295245)           265211.0
# 31    259                        BNG(page-blocks)           265174.0
# 32    156                           RandomRBF_0_0           300096.0
# 33    136            BNG(heart-c,nominal,1000000)           540810.0
# 34    266                            BNG(heart-c)           541436.0
# 35  42468                     hls4ml_lhc_jets_hlf           167851.0
# 36   1186                         BNG(eucalyptus)           289779.0
# 37  41671                       microaggregation2            11162.0
# 38   4538       GesturePhaseSegmentationProcessed             2950.0
# 39  42641                               phish_url             5342.0
# 40  41163                                 dilbert             2049.0
# 41    116   BNG(bridges_version1,nominal,1000000)           422711.0
# 42    253                   BNG(bridges_version1)           423139.0
# 43    129        BNG(dermatology,nominal,1000000)           304611.0
# 44    263                        BNG(dermatology)           304589.0
# 45    182                                satimage             1531.0
# 46   1183                           BNG(satimage)           238391.0
# 47     70             BNG(anneal,nominal,1000000)           759513.0
# 48    244                             BNG(anneal)           759652.0
# 49   1475             first-order-theorem-proving             2554.0
#
#     MinorityClassSize  NumberOfClasses  NumberOfFeatures  NumberOfInstances  \
# 0              4335.0              3.0               7.0            44819.0
# 1              1323.0              3.0               9.0             4177.0
# 2             12555.0              3.0              10.0            55296.0
# 3             12447.0              3.0              10.0            55296.0
# 4             67089.0              3.0              10.0           798964.0
# 5              1393.0              3.0              13.0          1000000.0
# 6            277674.0              3.0              14.0          1000000.0
# 7              2760.0              3.0              17.0            20000.0
# 8                93.0              3.0              22.0             3772.0
# 9              2870.0              3.0              28.0            10936.0
# 10               14.0              3.0              30.0             3772.0
# 11             1653.0              3.0              41.0             5000.0
# 12           330548.0              3.0              41.0          1000000.0
# 13           330606.0              3.0              41.0          1000000.0
# 14             6449.0              3.0              43.0            67557.0
# 15              145.0              3.0              47.0             4704.0
# 16            11357.0              3.0              50.0           101766.0
# 17              767.0              3.0              61.0             3190.0
# 18              765.0              3.0             181.0             3186.0
# 19              328.0              4.0               5.0             5456.0
# 20              328.0              4.0               9.0            12958.0
# 21            16553.0              4.0              19.0          1000000.0
# 22            16508.0              4.0              19.0          1000000.0
# 23           235618.0              4.0              19.0          1000000.0
# 24              328.0              4.0              25.0             5456.0
# 25               34.0              4.0              30.0             3772.0
# 26              677.0              4.0              30.0          1000000.0
# 27             1687.0              4.0              55.0            83733.0
# 28                2.0              5.0               9.0            12960.0
# 29               28.0              5.0              11.0             5473.0
# 30             1558.0              5.0              11.0           295245.0
# 31             1486.0              5.0              11.0           295245.0
# 32            92713.0              5.0              11.0          1000000.0
# 33             1618.0              5.0              14.0          1000000.0
# 34             1609.0              5.0              14.0          1000000.0
# 35           161066.0              5.0              17.0           830000.0
# 36           142795.0              5.0              20.0          1000000.0
# 37              743.0              5.0              21.0            20000.0
# 38              998.0              5.0              33.0             9873.0
# 39             2477.0              5.0              80.0            18982.0
# 40             1913.0              5.0            2001.0            10000.0
# 41            95098.0              6.0              13.0          1000000.0
# 42            95207.0              6.0              13.0          1000000.0
# 43            54922.0              6.0              35.0          1000000.0
# 44            55693.0              6.0              35.0          1000000.0
# 45              625.0              6.0              37.0             6430.0
# 46            96502.0              6.0              37.0          1000000.0
# 47              597.0              6.0              39.0          1000000.0
# 48              555.0              6.0              39.0          1000000.0
# 49              486.0              6.0              52.0             6118.0
#
#     NumberOfNumericFeatures  NumberOfCategoricalFeatures
# 0                       6.0                          1.0
# 1                       7.0                          2.0
# 2                       0.0                         10.0
# 3                       2.0                          8.0
# 4                       9.0                          1.0
# 5                       0.0                         13.0
# 6                      13.0                          1.0
# 7                      16.0                          1.0
# 8                      21.0                          1.0
# 9                      24.0                          4.0
# 10                      6.0                         24.0
# 11                     40.0                          1.0
# 12                      0.0                         41.0
# 13                     40.0                          1.0
# 14                      0.0                         43.0
# 15                     20.0                         27.0
# 16                     13.0                         37.0
# 17                      0.0                         61.0
# 18                      0.0                        181.0
# 19                      4.0                          1.0
# 20                      0.0                          9.0
# 21                      0.0                         19.0
# 22                      3.0                         16.0
# 23                     18.0                          1.0
# 24                     24.0                          1.0
# 25                      6.0                         24.0
# 26                      0.0                         30.0
# 27                     54.0                          1.0
# 28                      0.0                          9.0
# 29                     10.0                          1.0
# 30                      0.0                         11.0
# 31                     10.0                          1.0
# 32                     10.0                          1.0
# 33                      0.0                         14.0
# 34                      6.0                          8.0
# 35                     16.0                          1.0
# 36                     14.0                          6.0
# 37                     20.0                          1.0
# 38                     32.0                          1.0
# 39                     79.0                          1.0
# 40                   2000.0                          1.0
# 41                      0.0                         13.0
# 42                      3.0                         10.0
# 43                      0.0                         35.0
# 44                      1.0                         34.0
# 45                     36.0                          1.0
# 46                     36.0                          1.0
# 47                      0.0                         39.0
# 48                      6.0                         33.0
# 49                     51.0                          1.0

# %% [markdown]
# # Discussion / Would like to hear your opinion
#
# **I think we should**
# 1. Cap the number of instances and features.
#
#     E.g. with max 50k inscantes and 20 features we only get 26 regression, 50 binary, and 13 multiclass datasets.
#     What do you think? Should we go with these (not 150 datasets in total) or increase the caps so that we get 50 dataset for each tasks.
#
# 2. Try to remove this (probably) very similar datasets
#
#     E.g. for the binary tasks we get a lot of these `FOREX_*` datasets, which are probably very similar
#
#
# 3. Because the number of available datasets droped very quickly, we should not divide them further, e.g., depending on their features (numerical, categorical, mixed)
#
#     However, it could be interesting to look at this later on if we find outliers after imputation.
#     Outliere means all experimental settings are the same but an imputation method performs on dataset `A` much worse than on dataset `B`
